# %% [markdown]
# Import relevant packages

# %%
import numpy as np # this is our standard 'do some efficient matrix maths' package
import matplotlib.pyplot as plt # this is our standard plotting package
import glob # help us list files and recognise pathnames
import os # this package provides general functionality for our operating systems
import ee # this is the earthengine-api package
import geemap.foliumap as emap # this imports a method of creating interactive maps with geemap
import requests # requests is a HTTP library and so it will enable us to send out HTTP requests to get data
import rasterio # Enable us to work efficeintly with gridded raster datasets in python
from pyproj import Geod # pyproj helps us work with coordinate transformations and projections
import logging
logging.getLogger('rasterio').setLevel(logging.ERROR)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Authorise Google Earth Engine

# %%
ee.Authenticate()
ee.Initialize(project="uksa-training-course-materials")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Obtain data from Google Earth Engine

# %%
# we define the path
path='/home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/'

# check if the directory already exists
isExist = os.path.exists(path)
if not isExist:
   # Create a new directory because it does not exist
   os.makedirs(path) #we create the directory
   print("Created directory!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Download the data collection

# %%
def obtain_data(region, start_date, end_date, bands, collection_of_interest, include_end_date=False, max_cloud_cover=15):
    """
    region (geometry): region of interest
    start_date (str): Starting year for the Sentinel-2 imagery.
    end_data (str): Ending year for the Sentinel-2 imagery.
    bands(list): Bands to select from the surface reflectance product B2, B3, B4, and B8 correspond to Blue, Green, Red, and NIR.
    collection_of_interest (str): Earth ENgine Catalogue Data collection of interest
    max_cloud_cover (float): Max percentage of cloud coverage allowed - if the cloud coverage is higher, the imgage is not downloaded
    """

    start_date = ee.Date(start_date)

    if include_end_date:
        end_date = ee.Date(end_date)
    else:
        end_date = ee.Date(end_date).advance(-1, "day")

    # Filter input collections by desired date range, region and cloud coverage.
    criteria  = ee.Filter.And(
        ee.Filter.geometry(region),
        ee.Filter.date(start_date, end_date)
    )
    #'CLOUD_COVER' for Landsat.
    SAT = ee.ImageCollection(collection_of_interest) \
                      .filter(criteria) \
                      .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', max_cloud_cover))
    #Selects up to 5 images with the lowest cloud coverage.
    SAT = SAT.sort('CLOUDY_PIXEL_PERCENTAGE').limit(5).select(bands)
    
    image_collections = {
        'SAT': SAT,
        }

    return image_collections
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def download_data(filepath, region, scale_dict, start_date, end_date, bands, collection_of_interest, \
                  desired_collections=None, include_end_date=False, max_cloud_cover=15, overwrite=False):
    """
    filepath (str): Path to the directory where the data will be stored
    region (geometry): region of interest
    scale_dict (str): spatial resolution requested
    start_date (str): Starting year for the Sentinel-2 imagery.
    end_date (str): Ending year for the Sentinel-2 imagery.
    bands(list): Bands to select from the surface reflectance product B2, B3, B4, and B8 correspond to Blue, Green, Red, and NIR.
    collection_of_interest (str): Earth Eggine Catalogue Data collection of interest
    include_end_date (bool): either False or True
    max_cloud_cover (float): max percentage of cloud coverage allowed - if the cloud coverage is higher, the img is not downloaded
    overwrite(bool): either False or True
    """

    # Obtains all image collections defined in the request function for
    # the chosen test district and date range, with maximum n% cloud cover.
    image_collections = obtain_data(
        region,
        start_date,
        end_date,
        bands,
        collection_of_interest,
        include_end_date,
        max_cloud_cover,
    )

    # Filters out unwanted collections if defined above.
    if desired_collections:
        image_collections = {
            collection: image_collections[collection] \
            for collection in desired_collections
        }

    # Creates a subfolder in the base directory for the start date
    out_dir = f'{filepath}/{start_date}'
    if not os.path.isdir(out_dir):
        os.mkdir(out_dir)

    # Iterating through each image collection.
    for collection_name, collection in image_collections.items():
        print(collection_name)
        # Counts the number of images in a collection.
        collection_size = collection.size().getInfo()

        # Skips the image collection if it contains no images.
        if collection_size == 0:
            print('No images in collection, skipping.')
            continue

        # Creates additional subfolders for each image collection.
        collection_dir = f'{out_dir}/{collection_name}'
        if not os.path.isdir(collection_dir):
            os.mkdir(collection_dir)

        # Counts number of .tif files already in image collection subfolder.
        tif_count = len(glob.glob1(collection_dir,"*.tif"))

        # Assumes the download for this collection is already complete and
        # therefore skips, provided the number of .tif files already in
        # chosen directory matches the number of images in the collection
        # and overwrite is set to False.
        if collection_size == tif_count and overwrite == False:
            print('Correct number of .tif files for image collection already in directory, skipping.')
            continue

        # Exports each image in the filtered image collection to
        # geoTIFF format.
        emap.ee_export_image_collection(
            collection,
            collection_dir,
            crs='EPSG:4326',
            scale=scale_dict[collection_name],
            region=region
        )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Creation of Google Drive Folder
filepath = '/home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/'
# check if the directory already exists
isExist = os.path.exists(filepath)
if not isExist:
   # Create a new directory because it does not exist
   os.makedirs(filepath) #we create the directory
   print("Created directory!")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Bounding box for Baihetan Dam
region = ee.Geometry.Rectangle([102.85, 27.1, 102.95, 27.3])

# Defines the desired pixel scale for each image, have set to the native resolution of each satellite.
scale_dict = {
    'SAT': 10 #Appropriate for B2, B3, B4, and B8
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#Select desired dates
years = ["2017","2018","2019","2020","2021","2022","2023", "2024"] #Years Sentinal-2 data is fully available for
months = ["01", "04", "07", "10"] #Every 3 months
#Creates a list of start and end dates
date_list=[]
date_list = [f"{year}-{month}-01" for year in years for month in months]
date_list.append("2025-01-01") #This will be the last date in dates
date_list.append("2025-04-01") #This will not be included in dates
dates = [(date_list[i], date_list[i+1]) for i in range(len(date_list)-1)][0:-1]

dates
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [('2017-01-01', '2017-04-01'),
#  ('2017-04-01', '2017-07-01'),
#  ('2017-07-01', '2017-10-01'),
#  ('2017-10-01', '2018-01-01'),
#  ('2018-01-01', '2018-04-01'),
#  ('2018-04-01', '2018-07-01'),
#  ('2018-07-01', '2018-10-01'),
#  ('2018-10-01', '2019-01-01'),
#  ('2019-01-01', '2019-04-01'),
#  ('2019-04-01', '2019-07-01'),
#  ('2019-07-01', '2019-10-01'),
#  ('2019-10-01', '2020-01-01'),
#  ('2020-01-01', '2020-04-01'),
#  ('2020-04-01', '2020-07-01'),
#  ('2020-07-01', '2020-10-01'),
#  ('2020-10-01', '2021-01-01'),
#  ('2021-01-01', '2021-04-01'),
#  ('2021-04-01', '2021-07-01'),
#  ('2021-07-01', '2021-10-01'),
#  ('2021-10-01', '2022-01-01'),
#  ('2022-01-01', '2022-04-01'),
#  ('2022-04-01', '2022-07-01'),
#  ('2022-07-01', '2022-10-01'),
#  ('2022-10-01', '2023-01-01'),
#  ('2023-01-01', '2023-04-01'),
#  ('2023-04-01', '2023-07-01'),
#  ('2023-07-01', '2023-10-01'),
#  ('2023-10-01', '2024-01-01'),
#  ('2024-01-01', '2024-04-01'),
#  ('2024-04-01', '2024-07-01'),
#  ('2024-07-01', '2024-10-01'),
#  ('2024-10-01', '2025-01-01')]

# %%
for start_date, end_date in dates:
    print(start_date, end_date)
    download_data(
        filepath=filepath,
        region=region,
        scale_dict=scale_dict,
        start_date=start_date,
        end_date=end_date,
        include_end_date=False,
        max_cloud_cover=15,
        bands=['B2', 'B3', 'B4', 'B8'], #Blue, Green, Red, and NIR
        collection_of_interest="COPERNICUS/S2_SR_HARMONIZED",
        desired_collections=None,
        overwrite=True
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2017-01-01 2017-04-01
# SAT
# No images in collection, skipping.
# 2017-04-01 2017-07-01
# SAT
# No images in collection, skipping.
# 2017-07-01 2017-10-01
# SAT
# No images in collection, skipping.
# 2017-10-01 2018-01-01
# SAT
# No images in collection, skipping.
# 2018-01-01 2018-04-01
# SAT
# Total number of images: 4
#
# Exporting 1/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-01-01/SAT/20180219T034759_20180219T034801_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b4a1064ae5e09add6d60e247484ead8f-6613bd68889d3e1a60eab233ffcbd346:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-01-01/SAT/20180219T034759_20180219T034801_T48RTR.tif
#
#
# Exporting 2/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-01-01/SAT/20180219T034759_20180219T034801_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/385e7ecd9c5b29df9a10f2b0de2bdfbd-1b69c790d165b4ee966ed19ca79a561c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-01-01/SAT/20180219T034759_20180219T034801_T48RTQ.tif
#
#
# Exporting 3/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-01-01/SAT/20180318T033529_20180318T034541_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/05b659df3a5c67becdbbca27b2640ae2-18b47801695f421198404398d94304e7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-01-01/SAT/20180318T033529_20180318T034541_T48RTR.tif
#
#
# Exporting 4/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-01-01/SAT/20180318T033529_20180318T034541_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e7b16245a2e7d9970227390942087952-c2a736a32eb55b9e69717332335ff21e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-01-01/SAT/20180318T033529_20180318T034541_T48RTQ.tif
#
#
# 2018-04-01 2018-07-01
# SAT
# No images in collection, skipping.
# 2018-07-01 2018-10-01
# SAT
# No images in collection, skipping.
# 2018-10-01 2019-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-10-01/SAT/20181221T035141_20181221T035144_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e67ff856462c556905c44cd731d90aaf-de4f3454e5fa32322f19bccfdd005626:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-10-01/SAT/20181221T035141_20181221T035144_T48RTQ.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-10-01/SAT/20181223T034149_20181223T034311_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1de695b8cc15b075d17823dc9130da11-546bae1d06877cc5f1bbc9b3f13d6d77:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-10-01/SAT/20181223T034149_20181223T034311_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-10-01/SAT/20181226T035149_20181226T035148_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/8a394bc5eedb7ff3d4aeee90bf1879b7-74cb6cc6e69fc6b5f2a5c1b0a3308a07:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-10-01/SAT/20181226T035149_20181226T035148_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-10-01/SAT/20181226T035149_20181226T035148_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5d3c17d4204313e21fab4bfabccbffb7-54dd4d2e78506c165da8fd075b343005:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-10-01/SAT/20181226T035149_20181226T035148_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2018-10-01/SAT/20181216T035149_20181216T035143_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3cbc8a4e08e4ecd5b5c31d04583dac6d-5589bb25c95e8d334c3e1a6ccc73e47e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2018-10-01/SAT/20181216T035149_20181216T035143_T48RTR.tif
#
#
# 2019-01-01 2019-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-01-01/SAT/20190326T034539_20190326T035038_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/874de7a478fed8831cf985f254b61c08-475a718a437df5e36e8cda89a298cb46:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-01-01/SAT/20190326T034539_20190326T035038_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-01-01/SAT/20190318T033531_20190318T034552_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/44f2df0870e8339da193811f5962cf67-97da9894c6063b7c64409f695159e82a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-01-01/SAT/20190318T033531_20190318T034552_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-01-01/SAT/20190216T033821_20190216T034214_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/88f4bc49cceeacb6a09105410cfd5ab6-6876866b919d719f129757035c889e6b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-01-01/SAT/20190216T033821_20190216T034214_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-01-01/SAT/20190214T034849_20190214T035821_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/0268735c99ac6bef296ea62b39565349-bb4ffc76a88a62576e67777830a7b3fc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-01-01/SAT/20190214T034849_20190214T035821_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-01-01/SAT/20190127T034021_20190127T034019_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/f9e73787f53b0583ce2f92a9ab8350cc-6c8be49b16bdcdb78cce63f2be17f9e0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-01-01/SAT/20190127T034021_20190127T034019_T48RTR.tif
#
#
# 2019-04-01 2019-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-04-01/SAT/20190412T033739_20190412T034932_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/073b47852dd27ab565b9b4e9dcd76287-049cc5d43f31885ec8493e12790a348f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-04-01/SAT/20190412T033739_20190412T034932_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-04-01/SAT/20190420T034541_20190420T034913_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1ce3e0649aaa45019d71e66085e126d9-4c7c085dc7b3e63e42ae64ae34505df4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-04-01/SAT/20190420T034541_20190420T034913_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-04-01/SAT/20190427T033541_20190427T033835_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3e6f5c092a6c37cbc2e1f60a6304ff43-55a61fbf0b5fb7f2261232ac666c1d53:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-04-01/SAT/20190427T033541_20190427T033835_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-04-01/SAT/20190407T033541_20190407T034651_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/24e314764eeef9636a9c3d1998383333-be20a51750fdca9c6e761259120e7306:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-04-01/SAT/20190407T033541_20190407T034651_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-04-01/SAT/20190427T033541_20190427T033835_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/f235d9b7db754b40ee055a6a296dde6e-268b95d810d6b1f23ddc9318752e7d03:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-04-01/SAT/20190427T033541_20190427T033835_T48RTQ.tif
#
#
# 2019-07-01 2019-10-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-07-01/SAT/20190815T033541_20190815T034352_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/74f00ca90f35adfac3e7751af2a0597f-6e156e3f2b525f77d7897dab5f5f92e6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-07-01/SAT/20190815T033541_20190815T034352_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-07-01/SAT/20190815T033541_20190815T034352_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/36e9df5b122b8ef9399184526f0889d4-0faaca9302ac3e6117dcc12d8e67716c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-07-01/SAT/20190815T033541_20190815T034352_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-07-01/SAT/20190813T034539_20190813T035439_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/6788fccb1c651eee0cd5db74ef6c1502-6feadb4dc4864f23975181af8ac5a583:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-07-01/SAT/20190813T034539_20190813T035439_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-07-01/SAT/20190813T034539_20190813T035439_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/d4b83e904f17dee8d276d17ecbe1ca0b-d9f11b0cfb24e11b1b0aa4a1e701fb3d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-07-01/SAT/20190813T034539_20190813T035439_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-07-01/SAT/20190818T034541_20190818T035402_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2d07b12ffdf0fdb133e809d8079f1548-c3cf3907691ae5558a922fcc6478dc64:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-07-01/SAT/20190818T034541_20190818T035402_T48RTR.tif
#
#
# 2019-10-01 2020-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-10-01/SAT/20191223T034141_20191223T034820_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/ddc0a2787dc5e397d8ae1ad9d83ead52-ce5d8a227c660b9080bcef2dbb4ff7a6:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-10-01/SAT/20191223T034141_20191223T034820_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-10-01/SAT/20191223T034141_20191223T034820_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2310ec6ae7fec52d0657ab3694ad8e27-34b88038e8b2aa1aac09f1ab19e33be3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-10-01/SAT/20191223T034141_20191223T034820_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-10-01/SAT/20191116T035021_20191116T035654_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/9066a0664127c238f41c93167ccaed70-6b3ea1886d150e0742d504985e774bf2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-10-01/SAT/20191116T035021_20191116T035654_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-10-01/SAT/20191123T034051_20191123T034700_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/9dcdf51d5ba662c16d48a8e922436db7-89bc69ddb872891d200a38f1ec775ce9:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-10-01/SAT/20191123T034051_20191123T034700_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2019-10-01/SAT/20191216T035141_20191216T035834_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5dcfcc5ee283d015eae0851bf3eb3f40-98d4da63d86f0aa5476e359f4c5cd220:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2019-10-01/SAT/20191216T035141_20191216T035834_T48RTR.tif
#
#
# 2020-01-01 2020-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-01-01/SAT/20200330T034529_20200330T035549_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b3f1878b24bf453db7ded4384564dc0e-1e69d8e2a56838cb8e2a03d28b0328b1:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-01-01/SAT/20200330T034529_20200330T035549_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-01-01/SAT/20200330T034529_20200330T035549_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/d8605b9966a9ca822b29064f10113661-9e0857309328e10ba8f6360669aac8b4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-01-01/SAT/20200330T034529_20200330T035549_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-01-01/SAT/20200312T033531_20200312T033828_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/264e73c61f8ccaa663e07db2e888b086-8a35a2850eb8753611926e5af3a27a89:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-01-01/SAT/20200312T033531_20200312T033828_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-01-01/SAT/20200307T033609_20200307T034830_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3f9bc41238d620e6fce2674c4b76abf7-3a016db666b46962148ddc3bc4151d6e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-01-01/SAT/20200307T033609_20200307T034830_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-01-01/SAT/20200327T033539_20200327T034640_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/6cb3527d2bdf3d88738e74ca2634e1ee-e290e649f869fa9be148336483788e32:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-01-01/SAT/20200327T033539_20200327T034640_T48RTQ.tif
#
#
# 2020-04-01 2020-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-04-01/SAT/20200401T033531_20200401T034606_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/feea4dd71504e236c8bc8d458131a5e9-679b6ca4ba5b432bd928f8990eca5e0b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-04-01/SAT/20200401T033531_20200401T034606_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-04-01/SAT/20200506T033529_20200506T034350_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2f750e1f50ae0f79bd5a38945bd77780-9d843837ffd292ce11896998f43f8f3d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-04-01/SAT/20200506T033529_20200506T034350_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-04-01/SAT/20200401T033531_20200401T034606_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/30b3a2650d39d91f13f5f9967c415cb1-76f2757d2ec0566fd5fb2af1b8a5c754:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-04-01/SAT/20200401T033531_20200401T034606_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-04-01/SAT/20200416T033529_20200416T034504_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/6c185d4d1af7ec26c8903c4735554b4f-d2fa66c398c87a6ec1ef7ddf0e29b802:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-04-01/SAT/20200416T033529_20200416T034504_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-04-01/SAT/20200506T033529_20200506T034350_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1a539d98342365056c12c079278da117-d3338445b170ca6ccbf9f1a0d964a25f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-04-01/SAT/20200506T033529_20200506T034350_T48RTQ.tif
#
#
# 2020-07-01 2020-10-01
# SAT
# Total number of images: 3
#
# Exporting 1/3: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-07-01/SAT/20200827T034539_20200827T040004_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1110335092c4fb4482ad8ee67aa3b461-422af31bd5cc73c9c3543894bf4f12e1:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-07-01/SAT/20200827T034539_20200827T040004_T48RTQ.tif
#
#
# Exporting 2/3: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-07-01/SAT/20200827T034539_20200827T040004_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e763dc79b7ff39a78d48e2d4912b9e60-59f90d34d07d4c8173a29ee7c2bd53a3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-07-01/SAT/20200827T034539_20200827T040004_T48RTR.tif
#
#
# Exporting 3/3: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-07-01/SAT/20200728T034539_20200728T035815_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/8878cb48857690e269ed026d049884e0-7bbc6d6103534ccde23dc4b83f059d8d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-07-01/SAT/20200728T034539_20200728T035815_T48RTQ.tif
#
#
# 2020-10-01 2021-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-10-01/SAT/20201225T035149_20201225T035149_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b7cd2cb40e4b0c309aee2638cc8fdbbe-e0beff46c4b986cc8d0469461c8e8e8b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-10-01/SAT/20201225T035149_20201225T035149_T48RTQ.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-10-01/SAT/20201125T035059_20201125T035102_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b6617daf93d87e86d24b6648ea108193-41a02bc5569238978188ce5739adaa44:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-10-01/SAT/20201125T035059_20201125T035102_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-10-01/SAT/20201212T034139_20201212T034138_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/cfff157bf8f46e407f37e43d19f96be6-f89455413718d4c0d004a081598bf568:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-10-01/SAT/20201212T034139_20201212T034138_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-10-01/SAT/20201120T035051_20201120T035303_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/fc1a36564e2c00071d16b28a1cdafeb5-d8c8636a57fd0cf49863ce1c3b3d1c78:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-10-01/SAT/20201120T035051_20201120T035303_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2020-10-01/SAT/20201227T034151_20201227T034917_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5390455573f73ceb10db9112c67fe329-7bffd57fb5d49b7cc27d4f6a56756135:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2020-10-01/SAT/20201227T034151_20201227T034917_T48RTQ.tif
#
#
# 2021-01-01 2021-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-01-01/SAT/20210315T034539_20210315T035627_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/c7df007e3db4c1288fb440455f75770e-7e436bc27d3f4eccf20043ad701caf7c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-01-01/SAT/20210315T034539_20210315T035627_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-01-01/SAT/20210327T033531_20210327T033851_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1e1104d473b06a8a7545d9f1b1cb82a1-3ae21d7f87230bb0e75354d347b287b3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-01-01/SAT/20210327T033531_20210327T033851_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-01-01/SAT/20210104T035139_20210104T035140_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/a43de9b20c6cb37327dee39e8cc77670-99e530c7371441d2dd52ec41cc4436b5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-01-01/SAT/20210104T035139_20210104T035140_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-01-01/SAT/20210315T034539_20210315T035627_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/99d06e4205f12b2a229207e076f0aa6d-3b5a90d4a12661d14e0b735428b4d687:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-01-01/SAT/20210315T034539_20210315T035627_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-01-01/SAT/20210223T034739_20210223T040005_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3d6af7be2f52f89d5137af59d207e968-d4e03cd9a16ddd8691004d687bf3544c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-01-01/SAT/20210223T034739_20210223T040005_T48RTQ.tif
#
#
# 2021-04-01 2021-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-04-01/SAT/20210421T033529_20210421T034803_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/8e0d37161312fbd0d76915cee9c7fb42-3c3e1cebb0d908b5ea4572850b4115c3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-04-01/SAT/20210421T033529_20210421T034803_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-04-01/SAT/20210421T033529_20210421T034803_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3d74fef24a26fba2528e3a8f0e8b4686-cf6b112f58ac935c13e391bc8961a89e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-04-01/SAT/20210421T033529_20210421T034803_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-04-01/SAT/20210426T033531_20210426T033850_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/cfbf3e19a05594f641fe30081005352a-496bf3af523dc85fca9301e9d2f9df16:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-04-01/SAT/20210426T033531_20210426T033850_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-04-01/SAT/20210605T033541_20210605T033840_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/7954e58d201c8255d9162607721febf4-32423d435545ee9e9e6636a79e5764fb:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-04-01/SAT/20210605T033541_20210605T033840_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-04-01/SAT/20210521T033539_20210521T034809_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3d19ca383bf1e46f5b0302924f59971e-46e11b428cef47771e6673a9aa1cfe63:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-04-01/SAT/20210521T033539_20210521T034809_T48RTQ.tif
#
#
# 2021-07-01 2021-10-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-07-01/SAT/20210802T034539_20210802T040023_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/faad640209ffac09a143eed4b967e7f2-dc6b22c12c37b15409cabbc0c1e32331:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-07-01/SAT/20210802T034539_20210802T040023_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-07-01/SAT/20210802T034539_20210802T040023_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/9b6301b485a34bcae5ee99c222be13fc-03d0e7898ba3fb581284640ef1f28bb3:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-07-01/SAT/20210802T034539_20210802T040023_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-07-01/SAT/20210921T034529_20210921T035816_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e1754a5dd2d5c9d80f879d36be469c7b-f459978def862bb127c9c390cf53b647:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-07-01/SAT/20210921T034529_20210921T035816_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-07-01/SAT/20210804T033541_20210804T033842_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5fcfa0cd18ee4c88531bc1749706c5d9-ba85884bfdefa92acd0d283e3b3c890e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-07-01/SAT/20210804T033541_20210804T033842_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-07-01/SAT/20210804T033541_20210804T033842_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/39e96d74dc1316c186a610745c17c6c5-ee293730bd2b7e1e4044b8c173802942:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-07-01/SAT/20210804T033541_20210804T033842_T48RTR.tif
#
#
# 2021-10-01 2022-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-10-01/SAT/20211120T035039_20211120T035040_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/f354c058b710a5411169761ce1037e14-69197492b59b6d29fcf5eff05e45c04c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-10-01/SAT/20211120T035039_20211120T035040_T48RTQ.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-10-01/SAT/20211105T034941_20211105T035710_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e35b0e5250edc3d696381a8dfc62ab11-240a2ac890208ed7a9f99933fe0f226b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-10-01/SAT/20211105T034941_20211105T035710_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-10-01/SAT/20211215T035151_20211215T035951_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/fa7d15a562fc3146e3a85c29a530b5fb-bb55ccc7dcadbedc120a6c9910a093cf:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-10-01/SAT/20211215T035151_20211215T035951_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-10-01/SAT/20211210T035139_20211210T035136_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/fdcd4bd092dcd0ebc3a8438a819a5fc3-8b4d17cea83156fcd9cacd97296167a5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-10-01/SAT/20211210T035139_20211210T035136_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2021-10-01/SAT/20211105T034941_20211105T035710_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1e53a566dc77f61209890d692af2e2c9-5d580325d44899b30d50e0992e045e9e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2021-10-01/SAT/20211105T034941_20211105T035710_T48RTQ.tif
#
#
# 2022-01-01 2022-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-01-01/SAT/20220320T034529_20220320T035813_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2593a12353951a1800893de5d9f15b0d-6862e3bd6da52776cb61ba23de35c69d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-01-01/SAT/20220320T034529_20220320T035813_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-01-01/SAT/20220305T034641_20220305T035210_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2ed99ba333a5d0048482fbce1b332c24-b70f0f14892c44a9d37f452c75202052:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-01-01/SAT/20220305T034641_20220305T035210_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-01-01/SAT/20220310T034559_20220310T035642_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/fd0531d327ba83ca14726af002ea0c24-76312991f4e376604c74b0709619dab4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-01-01/SAT/20220310T034559_20220310T035642_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-01-01/SAT/20220307T033609_20220307T034830_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/0852239b73e5f73cc5a7477e98e38973-223f7ccf4365a44f0c377903c947d9a0:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-01-01/SAT/20220307T033609_20220307T034830_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-01-01/SAT/20220218T034809_20220218T035254_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/886a1ed27acd8f5a4a783204e1e09541-5211b63aed4fdd7418efb654a44ce8d4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-01-01/SAT/20220218T034809_20220218T035254_T48RTQ.tif
#
#
# 2022-04-01 2022-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-04-01/SAT/20220424T034541_20220424T035621_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b3ca65f565743ddb89f6ce4e00da298a-3a8113254c800f6247c0c8dc9922defc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-04-01/SAT/20220424T034541_20220424T035621_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-04-01/SAT/20220411T033541_20220411T034207_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1850bbe276d3cba3606aeeb162dd2e7b-9f18b36648204695fde6433b3ab05c1b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-04-01/SAT/20220411T033541_20220411T034207_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-04-01/SAT/20220426T033529_20220426T034806_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/0d530844e167a2e16b4b3bb2c65df180-e7fa98823e91128ecd310e01c9ce6546:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-04-01/SAT/20220426T033529_20220426T034806_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-04-01/SAT/20220424T034541_20220424T035621_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/7578be93c04de7ae920023a554269078-d900e1189f62678c4f2369b0245b75de:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-04-01/SAT/20220424T034541_20220424T035621_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-04-01/SAT/20220429T034529_20220429T040011_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/d22818813a806e92d44123966ae001e6-fad8ca9ccc4006c96ac317eeed26a8a2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-04-01/SAT/20220429T034529_20220429T040011_T48RTR.tif
#
#
# 2022-07-01 2022-10-01
# SAT
# Total number of images: 4
#
# Exporting 1/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-07-01/SAT/20220715T033539_20220715T034817_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/bbc7c0dcc27d9928479275bf899a857a-39e445c646fea6985be7399cd871a470:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-07-01/SAT/20220715T033539_20220715T034817_T48RTR.tif
#
#
# Exporting 2/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-07-01/SAT/20220908T033551_20220908T034813_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/4648d9506c2888bb3a979aededc81faf-e75007c585c1cc7ca7f22cccae29822d:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-07-01/SAT/20220908T033551_20220908T034813_T48RTQ.tif
#
#
# Exporting 3/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-07-01/SAT/20220814T033539_20220814T034812_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1de7a6bbb675111dc271456c21da5910-0da2b70a71c5f65f9b7dd02e6c7a57e4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-07-01/SAT/20220814T033539_20220814T034812_T48RTR.tif
#
#
# Exporting 4/4: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-07-01/SAT/20220819T033551_20220819T034355_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/ef57a01dda3a06bcd7e8b594b3de24bd-49b73db79f86d64a38be7aa58a669a04:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-07-01/SAT/20220819T033551_20220819T034355_T48RTR.tif
#
#
# 2022-10-01 2023-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-10-01/SAT/20221130T035121_20221130T035254_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/483cc3da6e24199c9b905b85f199f5c5-3c6924a5ce332f0026e9f222326dac5f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-10-01/SAT/20221130T035121_20221130T035254_T48RTQ.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-10-01/SAT/20221120T035041_20221120T035143_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5b7a1583a02b52b1105991fd44fc6d69-d83a5d33b41fcf080f971285888b619b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-10-01/SAT/20221120T035041_20221120T035143_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-10-01/SAT/20221202T034119_20221202T034632_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/cc64fe2b5cc972bdf75053335449e269-0b427b0403dc152a92fd1b4e94f7f1cd:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-10-01/SAT/20221202T034119_20221202T034632_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-10-01/SAT/20221127T034101_20221127T035003_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3e772a14e3295c9367a0e13d9d6fe7e1-8b01f8daffc0e7ae523563fe6a1470db:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-10-01/SAT/20221127T034101_20221127T035003_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2022-10-01/SAT/20221117T034031_20221117T034256_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e053264de6c4beddc38e4495f8864204-6983c7eef9ff247041a0dc9c48c01f90:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2022-10-01/SAT/20221117T034031_20221117T034256_T48RTQ.tif
#
#
# 2023-01-01 2023-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-01-01/SAT/20230218T034811_20230218T035620_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2431c6b5ebdf3fa0e4902873bf0e36b6-31c61d48838c021006f9896b4ffb13c4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-01-01/SAT/20230218T034811_20230218T035620_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-01-01/SAT/20230203T034949_20230203T035735_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/d1dc5fc3ac7b665f7cbd9b312244bbf4-1feee9ec2a9d3eef7a2bb7f51429ad74:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-01-01/SAT/20230203T034949_20230203T035735_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-01-01/SAT/20230218T034811_20230218T035620_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/abf353cd043f333a0d74b521f2264122-ed07cdf4e1d2e8b1b4b67e1db33a09be:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-01-01/SAT/20230218T034811_20230218T035620_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-01-01/SAT/20230109T035131_20230109T035321_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/8bacde2fca43b0bcb8e3c9bf5d5c3adc-7325180ef2d625e869d02d7c13d856a7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-01-01/SAT/20230109T035131_20230109T035321_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-01-01/SAT/20230131T033959_20230131T034403_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/ccee0c28c386b529eae82fa6ad28ebf0-f3c6429b1e1efb22df38c8616b74e4a2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-01-01/SAT/20230131T033959_20230131T034403_T48RTR.tif
#
#
# 2023-04-01 2023-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-04-01/SAT/20230404T034539_20230404T040011_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e5a38e4b2480cfbad4dbf8e13d002c4c-8f2fc43c49e8fae91b003a1c99f9ec26:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-04-01/SAT/20230404T034539_20230404T040011_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-04-01/SAT/20230409T034541_20230409T040008_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/5b89e2585da93a0a7492147f533bcf43-4d459aeb6f01c8712998d7710b9b7205:getPixels
# Please wait ...
# ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1d19744077aac01bde87e42f9d97f653-e57aeda3aa0a3eb0bcffd878d5aebf6a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-04-01/SAT/20230409T034541_20230409T040008_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-04-01/SAT/20230521T033539_20230521T034748_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/338bcd0bfa1763c671b2d04da8f238b8-d037c6e307999e39a62bb99fe5eb160f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-04-01/SAT/20230521T033539_20230521T034748_T48RTQ.tif
#
#
# 2023-07-01 2023-10-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-07-01/SAT/20230903T033541_20230903T034948_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/bad59910e5203942e7f7f8d651754a72-40b43e5b5d8de0a1519c85e3a8d147ae:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-07-01/SAT/20230903T033541_20230903T034948_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-07-01/SAT/20230705T033541_20230705T034749_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/fe94deea9a567d89d366b33f20cca7c3-d88694c6c7f195c9d626c4fa4c8087e7:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-07-01/SAT/20230705T033541_20230705T034749_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-07-01/SAT/20230903T033541_20230903T034948_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/c5cd2440f99e222b0a6cad04f1927af3-36ff4de8c6d75f47a950a0dcc541b20c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-07-01/SAT/20230903T033541_20230903T034948_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-07-01/SAT/20230705T033541_20230705T034749_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/3a655ab0cf090eb8e282a2586a1f3c46-2bea08015313812d53a75b46db5d0f6b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-07-01/SAT/20230705T033541_20230705T034749_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-07-01/SAT/20230718T034541_20230718T035533_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/540aee55c3f7d51dd3786e94f53c922e-206e5643b80dad78faa1fca319e7749f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-07-01/SAT/20230718T034541_20230718T035533_T48RTQ.tif
#
#
# 2023-10-01 2024-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-10-01/SAT/20231127T034059_20231127T034817_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/7b4bf557e2fa9456d04b07aa7ea42454-1c43cdb5b79d49a752c9cc5386e1bc2a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-10-01/SAT/20231127T034059_20231127T034817_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-10-01/SAT/20231220T035149_20231220T035152_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/4fa738f3b252cbae4b27e69c88375151-a404191e8313017b238eff11969d0c01:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-10-01/SAT/20231220T035149_20231220T035152_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-10-01/SAT/20231220T035149_20231220T035152_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/d0e222a620e30812de260b0357c1efe1-a64b16c0dae234518a5e822c67bbef57:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-10-01/SAT/20231220T035149_20231220T035152_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-10-01/SAT/20231215T035141_20231215T035144_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/6168a898c256553854f75098c65cce18-cc70d445396bcca34986dbf76763e6ea:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-10-01/SAT/20231215T035141_20231215T035144_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2023-10-01/SAT/20231023T033811_20231023T034610_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/db7d560d372ffc26ed6d5ddf7c035f85-34b027a9ef4009d5854beedd03830e46:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2023-10-01/SAT/20231023T033811_20231023T034610_T48RTQ.tif
#
#
# 2024-01-01 2024-04-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-01-01/SAT/20240213T034851_20240213T035732_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/35162e4c7298724bfb585903a0841de6-03164d1cad019590d35a000819e5bf26:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-01-01/SAT/20240213T034851_20240213T035732_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-01-01/SAT/20240218T034819_20240218T035627_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/af05374f348d1fb78e0fd812e1165745-abe2a0ea66b1bb27fe4778b8d20d1894:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-01-01/SAT/20240218T034819_20240218T035627_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-01-01/SAT/20240309T034559_20240309T040022_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/4e3b786118a2c1b7f2041ce9870d4fd2-ce06fc54900da8812cb22bfa210abde8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-01-01/SAT/20240309T034559_20240309T040022_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-01-01/SAT/20240109T035129_20240109T035335_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b456d584acb18f36bad8c77067867ca2-adea53b4f118e384a8f22c104be863b8:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-01-01/SAT/20240109T035129_20240109T035335_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-01-01/SAT/20240316T033539_20240316T034351_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/1aeaa2404ed234eb7d24b3d79804808e-49675c2a7ae7cb93cc115d76b94ddd62:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-01-01/SAT/20240316T033539_20240316T034351_T48RTQ.tif
#
#
# 2024-04-01 2024-07-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-04-01/SAT/20240415T033539_20240415T034512_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/094cd5b362c0b7d79d423a3db2946292-9667eb693e528fa2eede0a3012dc9a90:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-04-01/SAT/20240415T033539_20240415T034512_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-04-01/SAT/20240415T033539_20240415T034512_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/0a32f09a1137897d7be20cb2dcf2107a-727a6e751bd2cf5ed782d7e53be1846c:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-04-01/SAT/20240415T033539_20240415T034512_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-04-01/SAT/20240425T033539_20240425T034742_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/41c2081aed4e12bccc18fc9d7e880daa-98cd8ef2000815322d110532db49f17e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-04-01/SAT/20240425T033539_20240425T034742_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-04-01/SAT/20240405T033529_20240405T034350_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/37fc32865e8916a3a6dcb59b1fb192e8-991010ed2099581197bfffe9377b0b29:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-04-01/SAT/20240405T033529_20240405T034350_T48RTR.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-04-01/SAT/20240523T034531_20240523T035538_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b6e9e23596b7a64464a46cc1d44867f4-5a44b358f764b70b9df3e798b94ea773:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-04-01/SAT/20240523T034531_20240523T035538_T48RTR.tif
#
#
# 2024-07-01 2024-10-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-07-01/SAT/20240813T033539_20240813T035000_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/067e840756a4ba731b4493f13200d49e-639e4c17ac72d140a92c93c77d95e241:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-07-01/SAT/20240813T033539_20240813T035000_T48RTR.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-07-01/SAT/20240813T033539_20240813T035000_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/32c2246126b49ef1f86a1f3cb0a31b60-bc1e90d728359043e9df666765075491:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-07-01/SAT/20240813T033539_20240813T035000_T48RTQ.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-07-01/SAT/20240801T034541_20240801T035025_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/2d2d10a54c8cfabb1710b5b3a3790237-3b90b7c9349748fb85801d1fe6a11d13:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-07-01/SAT/20240801T034541_20240801T035025_T48RTR.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-07-01/SAT/20240801T034541_20240801T035025_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/28aba9677761293c7ca274cd82be393b-58d470f2673d5c6ce5671971baa8e63a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-07-01/SAT/20240801T034541_20240801T035025_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-07-01/SAT/20240821T034531_20240821T035338_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/c8702194afc2d8d9334e1b7a63eef7a3-42efbfc87078d417ce2c684d14a71399:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-07-01/SAT/20240821T034531_20240821T035338_T48RTR.tif
#
#
# 2024-10-01 2025-01-01
# SAT
# Total number of images: 5
#
# Exporting 1/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-10-01/SAT/20241229T035151_20241229T035340_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/53b2c18f9f008ba675a6afa9527e8770-a9c610cf877c84155daf15ec0359b45a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-10-01/SAT/20241229T035151_20241229T035340_T48RTQ.tif
#
#
# Exporting 2/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-10-01/SAT/20241229T035151_20241229T035340_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/6536490abf45465077cfcf0b4ea70a49-173ce1fe2f8b9ef69708e42318bf4c98:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-10-01/SAT/20241229T035151_20241229T035340_T48RTR.tif
#
#
# Exporting 3/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-10-01/SAT/20241114T034919_20241114T035614_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/b27cef23ef39df7f1eb37edb328ad972-4c2d3a5038193a3a3b2754e310465bc4:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-10-01/SAT/20241114T034919_20241114T035614_T48RTQ.tif
#
#
# Exporting 4/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-10-01/SAT/20241226T034151_20241226T034333_T48RTQ.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/e5c84b608483404fc29538ed66d090ab-c80016e78120b47f7125a31c6d74056f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-10-01/SAT/20241226T034151_20241226T034333_T48RTQ.tif
#
#
# Exporting 5/5: /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2//2024-10-01/SAT/20241114T034919_20241114T035614_T48RTR.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/uksa-training-course-materials/thumbnails/62cde88295161c3d14f8aa4710f42525-a5e5b2f9c07fecaf103b4fe7da1d2d7f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/data/Tutorial_data/scratch/GEE_test/roblar/S2/2024-10-01/SAT/20241114T034919_20241114T035614_T48RTR.tif
